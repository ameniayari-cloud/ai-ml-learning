# %% [markdown]
# # Module 4 - Sujets Avancés\nNotebook interactif de pratique.\n

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
texts = ['bonjour ai', 'machine learning avancé']
TfidfVectorizer().fit_transform(texts).shape
