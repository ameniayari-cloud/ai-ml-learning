# %% [markdown]
# # Projet 08 - Text Classification\nNotebook interactif de pratique.\n

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
X = ['ai', 'sport', 'finance']
TfidfVectorizer().fit_transform(X).shape
