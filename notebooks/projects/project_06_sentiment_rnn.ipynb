# %% [markdown]
# # Projet 06 - Sentiment RNN\nNotebook interactif de pratique.\n

# %%
import tensorflow as tf
(x_train, y_train), _ = tf.keras.datasets.imdb.load_data(num_words=5000)
len(x_train), len(y_train)
